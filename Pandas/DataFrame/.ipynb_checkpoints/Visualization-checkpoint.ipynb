# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('df1', index_col=0)
df2 = pd.read_csv('df2')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df1['A'].hist()

plt.style.use('bmh')
df1['A'].hist()

plt.style.use('dark_background')
df1['A'].hist()

plt.style.use('fivethirtyeight')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
df2 = pd.read_csv('df2')
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
df2 = pd.read_csv('df2')
df2.head()
df2.plot.bar()
df2.plot.bar(stacked = True)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
df1 = pd.read_csv('df1')
df1['A'].plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
df1 = pd.read_csv('df1')
df1.plot.line(x = df1.index, y ='B', figsize =(12, 3), lw = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-f3d06d029d6a> in <module>
#       1 import matplotlib.pyplot as plt
#       2 df1 = pd.read_csv('df1')
# ----> 3 df1.plot.line(x = df1.index, y ='B', figsize =(12, 3), lw = 1)
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#    1015         as coordinates.
#    1016         """
# -> 1017         return self(kind="line", x=x, y=y, **kwargs)
#    1018
#    1019     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     912                 if is_integer(x) and not data.columns.holds_integer():
#     913                     x = data_cols[x]
# --> 914                 elif not isinstance(data[x], ABCSeries):
#     915                     raise ValueError("x must be a label or position")
#     916                 data = data.set_index(x)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',\n       '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',\n       ...\n       '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20', '2002-09-21',\n       '2002-09-22', '2002-09-23', '2002-09-24', '2002-09-25', '2002-09-26'],\n      dtype='object', length=1000)] are in the [columns]"

# %%
import matplotlib.pyplot as plt
df1 = pd.read_csv('df1')
df1.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
import matplotlib.pyplot as plt
df1 = pd.read_csv('df1')
df1.plot.scatter(x ='A', y ='B', c ='C', cmap ='coolwarm')
df1.plot.scatter(x ='A', y ='B', s = df1['C']*200)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
import matplotlib.pyplot as plt
df2 = pd.read_csv('df2')
df2.plot.box() # Can also pass a by = argument for groupby
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
df = pd.DataFrame(np.random.randn(1000, 2), columns =['a', 'b']) 
df.plot.hexbin(x ='a', y ='b', gridsize = 25, cmap ='Oranges')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
import matplotlib.pyplot as plt
df2 = pd.read_csv('df2')
df2['a'].plot.kde()
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import pandas as pd
df = pd.read_csv('nba.csv')
df.shape
df.iloc[0:5,:]
df.iloc[:,:]
df.iloc[5:,:5]                   ''''''''''''''''''''''''''''''''
df.loc[0:5,:]
df.loc[:5, "Team"]
df.describe()
df.corr()
df.rank()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0     35.0   23.0    10.5     224.5  177.0   125.5    24.5    294.0   350.0
# 1    172.0   23.0   457.0     313.0  177.0   248.5   303.0    179.0   337.0
# 2    212.0   23.0   361.0     406.5  256.0   211.5   138.5     27.0     NaN
# 3    356.0   23.0   354.0     406.5   53.5   211.5    36.5    103.0   125.0
# 4    217.0   23.0   153.0     128.5  321.5    54.0   287.0      NaN   300.0
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453  396.0  435.0   153.0     224.5  217.5   150.0   126.5     30.5   206.0
# 454  362.0  435.0   342.5     224.5  131.0    22.5    21.5      NaN    64.0
# 455  418.0  435.0   298.0      39.5  217.5   455.5   420.0      NaN   232.5
# 456  195.0  435.0   333.5      39.5  217.5   430.0   287.0    131.5    80.0
# 457    NaN    NaN     NaN       NaN    NaN     NaN     NaN      NaN     NaN
#
# [458 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
df['Age'].hist(bins=10)

df.boxplot(column='Age', by='Number')

x = df['Age']
y = df['Number']
plt.scatter(x,y, label='stars', color='m', marker='*',s=30)
plt.xlabel('Age')
plt.ylabel('Number')
plt.show()

# %%
import pandas as pd
s1 = pd.Series([0, 4, 8]) 
s2 = pd.Series([1, 5, 9]) 
s3 = pd.Series([2, 6, 10]) 

dframe = pd.DataFrame([s1,s2,s3])
dframe.columns = ['Geeks','For','Geeks']

dframe.to_csv('geek.csv',index=False)
dframe.to_csv('geek1.csv',index=True)

# %%
import pandas as pd
import numpy as np
dframe = pd.DataFrame({'Geeks': [23, 24, 22],  
                       'For': [10, 12, np.nan], 
                       'geeks': [0, np.nan, np.nan]}, 
                       columns =['Geeks', 'For', 'geeks'])
print('axis=0')
dframe.dropna(inplace=True)
print(dframe,'\n')                            ''''''''''''''''''''''''''''''''''''

print('axis=1')
dframe.dropna(axis=1, inplace=True)
print(dframe)
# Out:
# axis=0
#    Geeks   For  geeks
# 0     23  10.0    0.0
#
# axis=1
#    Geeks   For  geeks
# 0     23  10.0    0.0

# %%
import numpy as np
import pandas as pd
dframe = pd.DataFrame({'Geeks': [23, 24, 22],  
                        'For': [10, 12, np.nan], 
                        'geeks': [0, np.nan, np.nan]}, 
                        columns = ['Geeks', 'For', 'geeks']) 
dframe.fillna(value=dframe.mean(), inplace=True)
print(dframe)

dframe['For'].fillna(value=dframe['For'].mean(),inplace=True)
print(dframe)
# Out:
#    Geeks   For  geeks
# 0     23  10.0    0.0
# 1     24  12.0    0.0
# 2     22  11.0    0.0
#    Geeks   For  geeks
# 0     23  10.0    0.0
# 1     24  12.0    0.0
# 2     22  11.0    0.0

# %%
import pandas as pd
import numpy as np
dframe = pd.DataFrame({'Geeks': [23, 24, 22, 22, 23, 24],  
                        'For': [10, 12, 13, 14, 15, 16], 
                        'geeks': [122, 142, 112, 122, 114, 112]}, 
                        columns = ['Geeks', 'For', 'geeks'])  

# Apply groupby and aggregate function 
# max to find max value of column  
  
# &quot;For&quot; and column &quot;geeks&quot; for every 
# different value of column &quot;Geeks&quot;. 

print(dframe.groupby(['Geeks']).max())
# Out:
#        For  geeks
# Geeks
# 22      14    122
# 23      15    122
# 24      16    142

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#% matplotlib inline            ''''''''''''''''''''''''''''''''''''''

df = pd.read_csv('nba.csv')
df.head()
df.boxplot(by ='Age', column =['Number'], grid = False) 
df.boxplot(by ='Height', column =['Age'], grid = False)
# Out:
# <AxesSubplot:title={'center':'Age'}, xlabel='Height'>

# %%
import seaborn as sns
tips = sns.load_dataset('winequality-red.csv') 
print(tips.head())
# sns.set_style("whitegrid")
# sns.boxplot(x = 'day', y = 'total_bill', data = tips)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-ca170ab3c652> in <module>
#       1 import seaborn as sns
# ----> 2 tips = sns.load_dataset('winequality-red.csv')
#       3 print(tips.head())
#       4 # sns.set_style("whitegrid")
#
# ~\anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     484         if not os.path.exists(cache_path):
#     485             if name not in get_dataset_names():
# --> 486                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     487             urlretrieve(full_path, cache_path)
#     488         full_path = cache_path
#
# ValueError: 'winequality-red.csv' is not one of the example datasets.
